# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import pytesseract
import re

def extract(text):
    i = 0
    p = re.compile('.*\d{2}\.\d{3}\.\d{3}\/\d{4}-\d{2}.*')
    for line in iter(text.splitlines()):
        s = p.match(line)
        if s:
            print(s.group(), i)
            i += 1

files_path = [os.path.abspath(x) for x in os.listdir('./images') if x.endswith('.jpg')]

base_teste = []

#extraindo as características das imagens na base de dados
for i in files_path:
    diretorio, arquivo = os.path.split(i)
    imagem = cv2.imread(diretorio + '/images/' + arquivo, 0)
    text = pytesseract.image_to_string(imagem, lang='por')
    print('='*80)
    extract(text)
    print('='*80)
    plt.gray()
    plt.imshow(imagem)
    plt.show()
# Out:
# ================================================================================
# ================================================================================
# ================================================================================
# CNPJ:63.004.030/0001-96 0
# ================================================================================
# ================================================================================
# ================================================================================
# ================================================================================
# CPF/CNPJ: 01.613.606/0001-93 Inscrição Municipal: 0.214.441-7 Inscrição Estadual: — 0
# ================================================================================
# ================================================================================
# CNPJ Nº: 43.962.539/0001-34 Inscrição Estadual Nº.: 110.348.074.110 0
# ================================================================================
# ================================================================================
# Usuário: 14.753.740/0001-03 - NF-e - Nota Fiscal Eletrônica de Serviços - São Paulo - Página 1 de 1 0
# CPF/CNPJ: 14.753.740/0001-03 Inscrição Municipal: 4.430.719-5 1
# ================================================================================

# %%
text = '67.824.422/0001-52'
p = re.compile('.*\d{2}\.\d{3}\.\d{3}\/\d{4}-\d{2}.*')
k = p.match(text)
print(k)
# Out:
# None

# %% [markdown]
# ## Binarizar imagem

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import pytesseract
import re

def extract(text):
    i = 0
    p = re.compile('.*\d{2}\.\d{3}\.\d{3}\/\d{4}-\d{2}.*')
    for line in iter(text.splitlines()):
        s = p.match(line)
        if s:
            print(s.group(), i)
            i += 1

files_path = [os.path.abspath(x) for x in os.listdir('./images') if x.endswith('.jpg')]

base_teste = []

#extraindo as características das imagens na base de dados
for i in files_path:
    diretorio, arquivo = os.path.split(i)
    imagem = cv2.imread(diretorio + '/images/' + arquivo, 0)
    text = pytesseract.image_to_string(imagem, lang='por')
    print('='*80)
    extract(text)
    print('='*80)

    ret,W = cv2.threshold(imagem,50,255,cv2.THRESH_BINARY_INV)
    text = pytesseract.image_to_string(W, lang='por')
    print('='*80)
    extract(text)
    print('='*80)
    
    plt.figure(figsize=(10,10))
    plt.gray()
    plt.imshow(W)
    plt.show()
# Out:
# ================================================================================
# ================================================================================
# ================================================================================
# ================================================================================
# ================================================================================
# CNPJ:63.004.030/0001-96 0
# ================================================================================
# ================================================================================
# ================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-8d8ab134d738> in <module>
#      23     diretorio, arquivo = os.path.split(i)
#      24     imagem = cv2.imread(diretorio + '/images/' + arquivo, 0)
# ---> 25     text = pytesseract.image_to_string(imagem, lang='por')
#      26     print('='*80)
#      27     extract(text)
#
# ~/Documents/VISAO/virtual/lib/python3.6/site-packages/pytesseract/pytesseract.py in image_to_string(image, lang, config, nice, output_type)
#     307         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     308         Output.STRING: lambda: run_and_get_output(*args),
# --> 309     }[output_type]()
#     310
#     311
#
# ~/Documents/VISAO/virtual/lib/python3.6/site-packages/pytesseract/pytesseract.py in <lambda>()
#     306         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     307         Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 308         Output.STRING: lambda: run_and_get_output(*args),
#     309     }[output_type]()
#     310
#
# ~/Documents/VISAO/virtual/lib/python3.6/site-packages/pytesseract/pytesseract.py in run_and_get_output(image, extension, lang, config, nice, return_bytes)
#     216         }
#     217
# --> 218         run_tesseract(**kwargs)
#     219         filename = kwargs['output_filename_base'] + os.extsep + extension
#     220         with open(filename, 'rb') as output_file:
#
# ~/Documents/VISAO/virtual/lib/python3.6/site-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice)
#     186         raise TesseractNotFoundError()
#     187
# --> 188     status_code, error_string = proc.wait(), proc.stderr.read()
#     189     proc.stdin.close()
#     190     proc.stdout.close()
#
# /usr/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
#    1478                         # Check the pid and loop as waitpid has been known to
#    1479                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1422             """All callers to this function MUST hold self._waitpid_lock."""
#    1423             try:
# -> 1424                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1425             except ChildProcessError:
#    1426                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
